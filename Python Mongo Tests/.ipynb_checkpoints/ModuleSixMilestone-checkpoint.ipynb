# %%
from jupyter_plotly_dash import JupyterDash

import dash
import dash_leaflet as dl
from dash import dcc
from dash import html
import plotly.express as px
from dash import dash_table
from dash.dash_table.Format import Group
from dash.dependencies import Input, Output


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pymongo import MongoClient




#### FIX ME #####
# change animal_shelter and AnimalShelter to match your CRUD Python module file name and class name
#from animal_shelter import AnimalShelter


from aacCRUD import CRUD



###########################
# Data Manipulation / Model
###########################
# FIX ME update with your username and password and CRUD Python module name

usr = 'aacuser'
pw = 'yh0okRBJkaFVCJnw'

str = "mongodb+srv://" + usr + ":" + pw + "@cluster0.cyqsq." + "mongodb.net/?retryWrites=true&w=majority"
#shelter = CRUD(str, 'AAC', 'animals')
shelter = CRUD('mongodb://localhost:27017', 'AAC', 'animals')

cursor = shelter.readAll()
df = pd.DataFrame.from_records((cursor))
df = df.iloc[:,1:]
print(df)

# class read method must support return of cursor object and accept projection json input

#########################
# Dashboard Layout / View
#########################
app = JupyterDash('SimpleExample')

app.layout = html.Div([
    html.Div(id='hidden-div', style={'display':'none'}),
    html.Center(html.B(html.H1('SNHU CS-340 Dashboard'))),
    html.Hr(),
    dash_table.DataTable(
        id='datatable-id',
        columns=[
            {"name": i, "id": i, "deletable": False, "selectable": True} for i in df.columns
        ],
        data=df.to_dict('records'),
        editable=False,
        filter_action="native",
        sort_action="native",
        sort_mode="multi",
        column_selectable=False,
        row_selectable=False,
        row_deletable=False,
        selected_columns=[],
        selected_rows=[],
        page_action="native",
        page_current=0,
        page_size=10,
        
        #FIXME: Set up the features for your interactive data table to make it user-friendly for your client

    ),
    html.Br(),
    html.Hr(),
    #html.Div(
    #        id='map-id',
    #        className='col s12 m6',
    #        )
])



#############################################
# Interaction Between Components / Controller
#############################################
#This callback will highlight a row on the data table when the user selects it
@app.callback(
    Output('datatable-id', 'style_data_conditional'),
    [Input('datatable-id', 'selected_columns')]
)
def update_styles(selected_columns):
    return [{
        'if': { 'column_id': i },
        'background_color': '#D2F3FF'
    } for i in selected_columns]


#@app.callback(
#    Output('map-id', "children"),
#    [Input('datatable-id', "derived_viewport_data")])
#def update_map(viewData):
#FIXME Add in the code for your geolocation chart
    

app
# Out:
#                          _id animal      breed  age   health neutered  \
# 0   62edadc4fea3e6dd0ea439c5    cat  shorthair    2     good    false
# 1   62edae57b0c3d39e9accc911    cat  shorthair    2     good    false
# 2   62edae6dab89df527584c0dc    cat  shorthair    2     good    false
# 3   62edaf031ef279ee99920bd7    cat  shorthair    2     good    false
# 4   62edaf26c807a57782b8b904    cat  shorthair    2     good    false
# 5   62edaf26c807a57782b8b905    cat       tabi    1     good    false
# 6   62edaf26c807a57782b8b906    cat  longthair    3    great    false
# 7   62edaf26c807a57782b8b907    cat  shorthair    2  average     true
# 8   62edaf26c807a57782b8b908    dog     french    5      bad     true
# 9   62edaf26c807a57782b8b909    cat     sphynx    6  average     true
# 10  62edaf26c807a57782b8b90a    cat       tabi    7  average     true
# 11  62edaf26c807a57782b8b90b    dog     buldog    4     good    false
# 12  62edaf26c807a57782b8b90c    cat  shorthair    4  average     true
# 13  62edaf26c807a57782b8b90d    dog     french    3  average     true
# 14  62edaf26c807a57782b8b90e    dog     poodle    7      bad    false
# 15  62edaf26c807a57782b8b90f    dog     french    2     good    false
# 16  62edaf26c807a57782b8b910    cat  longthair    5     good    false
# 17  62edaf26c807a57782b8b911    cat  shorthair    7  average     true
# 18  62edaf26c807a57782b8b912    dog     french    2  average     true
# 19  62edaf26c807a57782b8b913    cat     sphynx    2  average     true
# 20  62edaf26c807a57782b8b914    cat       tabi    5      bad    false
# 21  62edaf26c807a57782b8b915    dog     buldog    7      bad    false
# 22  62edaf26c807a57782b8b916    cat   longhair    1  average     true
# 23  62edaf26c807a57782b8b917    cat  shorthair    6    great     true
# 24  62edaf26c807a57782b8b918    dog     poodle    6    great    false
# 25  62edaf26c807a57782b8b919    dog     buldog    3     good     true
# 26  62edaf26c807a57782b8b91a    cat     sphynx    5  average     true
# 27  62edaf26c807a57782b8b91b    cat     sphynx    4     good    false
# 28  62edaf26c807a57782b8b91c    dog   labrador    4  average    false
# 29  62edaf26c807a57782b8b91d    cat     sphynx    7      bad     true
# 30  62edaf26c807a57782b8b91e    cat  shorthair   16    great     true
# 31  62edaf26c807a57782b8b91f    dog     poodle   12    great    false
# 32  62edaf26c807a57782b8b920    dog     buldog   13     good     true
# 33  62edaf26c807a57782b8b921    cat     sphynx   12  average     true
# 34  62edaf26c807a57782b8b922    cat     sphynx   16     good    false
# 35  62edaf26c807a57782b8b923    dog   labrador   14  average    false
# 36  62edaf26c807a57782b8b924    cat     sphynx   15      bad    false
# 37  62edaf26c807a57782b8b925    dog     poodle   13    great    false
# 38  62edaf26c807a57782b8b926    dog     buldog    9     good     true
# 39  62edaf26c807a57782b8b927    cat     sphynx   11  average     true
# 40  62edaf26c807a57782b8b928    cat     sphynx    8     good    false
# 41  62edaf26c807a57782b8b929    dog   labrador    6  average    false
# 42  62edaf26c807a57782b8b92a    cat     sphynx   10      bad    false
# 43  62edaf26c807a57782b8b92b    dog     poodle   11    great     true
# 44  62edaf26c807a57782b8b92c    dog     buldog    8     good     true
# 45  62edaf26c807a57782b8b92d    cat     sphynx   12  average     true
# 46  62edaf26c807a57782b8b92e    cat     sphynx   11     good     true
# 47  62edaf26c807a57782b8b92f    dog   labrador    5  average     true
# 48  62edaf26c807a57782b8b930    cat     sphynx    9      bad     true
#
#          owner
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5         Marv
# 6         Adam
# 7          Jim
# 8    Sebastian
# 9        Sindy
# 10      Marvin
# 11      Samuel
# 12       Blake
# 13        Orit
# 14    Emmanuel
# 15    Gonzalez
# 16       Izeta
# 17      Justin
# 18       Daisy
# 19      Mickey
# 20     Charles
# 21     Juaquin
# 22     Clement
# 23      Orleon
# 24      Elijah
# 25      Prajat
# 26       Simon
# 27        Lyla
# 28         Sam
# 29        Seba
# 30    Clemente
# 31        Zeta
# 32  Prajatakan
# 33       Jayne
# 34     Hermina
# 35       Hasan
# 36     Sebasel
# 37       Zetal
# 38        Praj
# 39      Jaynee
# 40       Azeta
# 41      Hassan
# 42       Sadiy
# 43       Zerox
# 44        Asim
# 45    Shenelle
# 46       Spity
# 47         Tom
# 48        Numa
# <div>
#   <iframe src="/app/endpoints/794f7ee46e134736bd8fb83c32cd2ae2/" width=800 height=600 frameborder="0"></iframe>
#   <hr/><a href="/app/endpoints/794f7ee46e134736bd8fb83c32cd2ae2/" target="_new">Open in new window</a> for /app/endpoints/794f7ee46e134736bd8fb83c32cd2ae2/
# </div>
